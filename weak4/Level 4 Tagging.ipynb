# %% [markdown]
# ### Tagging

# %% [markdown]
# So here is Mr. James Wilson who wrote about Elon Musk. Here is the following content.
#
# ~~~~
# Musk was born on June 28, 1971, in Pretoria, Gauteng, South Africa,[27] the son of Maye Musk (née Haldeman), a model and dietician from Regina, Saskatchewan, Canada;[28] and Errol Musk, a South African electromechanical engineer, pilot and sailor. He has a younger brother, Kimbal (born 1972), and a younger sister, Tosca (born 1974).[28][29][30][31] His paternal grandmother was British, and he also has Pennsylvania Dutch ancestry,[32][33] and his maternal grandfather was American, from Minnesota.[34] After his parents divorced in 1980, Musk lived mostly with his father in the suburbs of Pretoria.[32]
#
# During his childhood he had an interest in reading and often did so for hours at a time.[35]
#
# At What age did Musk got interested in computing? At age 10, he developed an interest in computing with the Commodore VIC-20.[36] He taught himself computer programming at the age of 12, sold the code for a BASIC-based video game he created called Blastar, to a magazine called PC and Office Technology, for approximately $500. [37][38] A web version of the game is available online.[37][39]
#
# Musk was severely bullied throughout his childhood, and was once hospitalized when a group of boys threw him down a flight of stairs and then beat him until he lost consciousness.[40]
#
# Musk was initially educated at private schools, attending the English-speaking Waterkloof House Preparatory School.
#
# Mr. Singh helped Musk during his initial days when he was severely bullied during his childhood.
#
# Musk later graduated from Pretoria Boys High School and moved to Canada in June 1989, just before his 18th birthday,[41] after obtaining Canadian citizenship through his Canadian-born mother.[42][43] Although at the time Musk had to register to become a Canadian citizen, Bill C-37, which came into law in April of 2009, effectively made his Canadian citizenship retroactive to his birth since he was born in the first generation abroad to a Canadian-born mother. Therefore, with the law change, he is considered to have always been a Canadian citizen by birth.
# ~~~~

# %% [markdown]
# ### Part - 1
#
# 1. Tag the given content using POS Tagger
#
# 2. Default Tag the entire content with the tag which appears most number of times
#
# ### Part - 2
#
# Create your own Tagger using the following rules
#
# Let's try to understand some **Parts Of Speech**
#
# 1. **Possesion Noun (NN\$)** - any word which ends with **'s**
#     > ***Jennifer’s*** new handbag matches her shoes perfectly
# 2. **Gerund (VBG)** - any word which ends with **ing**
#     > ***Swimming*** in the ocean has been Sharon’s passion since she was five years old.
# 3. **Simple Past (VBD)** - any word which ends with **ed**
#     > We ***crossed*** the Channel yesterday.
# 4. **Modal (MD)** - any word which ends with **ould**
#     > He **should** not be late
# 5. **Third Singular Present (VBZ)** - any word which ends with **es**
#     > He **misses** her so much
# 6. **Numbers (CD)** - any number integer or decimal
#     > 24.90
# 7. **Plural Nouns (NNS)** - any word ending with **s**
#     > You stole my **ideas** and didn’t give me any credit.

# %% [markdown]
# # part 1

# %%
import nltk

from nltk.tokenize import PunktSentenceTokenizer,word_tokenize
passage = 'Musk was born on June 28, 1971, in Pretoria, Gauteng, South Africa,[27] the son of Maye Musk (née Haldeman), a model and dietician from Regina, Saskatchewan, Canada;[28] and Errol Musk, a South African electromechanical engineer, pilot and sailor. He has a younger brother, Kimbal (born 1972), and a younger sister, Tosca (born 1974).[28][29][30][31] His paternal grandmother was British, and he also has Pennsylvania Dutch ancestry,[32][33] and his maternal grandfather was American, from Minnesota.[34] After his parents divorced in 1980, Musk lived mostly with his father in the suburbs of Pretoria.[32].During his childhood he had an interest in reading and often did so for hours at a time.[35].At What age did Musk got interested in computing? At age 10, he developed an interest in computing with the Commodore VIC-20.[36] He taught himself computer programming at the age of 12, sold the code for a BASIC-based video game he created called Blastar, to a magazine called PC and Office Technology, for approximately $500. [37][38] A web version of the game is available online.[37][39].Musk was severely bullied throughout his childhood, and was once hospitalized when a group of boys threw him down a flight of stairs and then beat him until he lost consciousness.[40].Musk was initially educated at private schools, attending the English-speaking Waterkloof House Preparatory School.Mr. Singh helped Musk during his initial days when he was severely bullied during his childhood.Musk later graduated from Pretoria Boys High School and moved to Canada in June 1989, just before his 18th birthday,[41] after obtaining Canadian citizenship through his Canadian-born mother.[42][43] Although at the time Musk had to register to become a Canadian citizen, Bill C-37, which came into law in April of 2009, effectively made his Canadian citizenship retroactive to his birth since he was born in the first generation abroad to a Canadian-born mother. Therefore, with the law change, he is considered to have always been a Canadian citizen by birth.'
#passage1 = word_tokenize(passage)
#passage1

# %%
#tokenized = custom_sent_tokenize.tokenize(passage)
tagger = []
for i in (passage1):
    words = nltk.word_tokenize(i)
    tagged = nltk.pos_tag(words)
    tagger.append(tagged[0])

# %%
from collections import Counter
counts = nltk.FreqDist(tag for word,tag in (tagger))
#counts  =Counter(tag for word,tag in (tagger))
m= counts.most_common()
n = m[0][0]
nn = nltk.DefaultTagger(n)
nn.tag(passage1)
# Out:
# [('Musk', 'NN'),
#  ('was', 'NN'),
#  ('born', 'NN'),
#  ('on', 'NN'),
#  ('June', 'NN'),
#  ('28', 'NN'),
#  (',', 'NN'),
#  ('1971', 'NN'),
#  (',', 'NN'),
#  ('in', 'NN'),
#  ('Pretoria', 'NN'),
#  (',', 'NN'),
#  ('Gauteng', 'NN'),
#  (',', 'NN'),
#  ('South', 'NN'),
#  ('Africa', 'NN'),
#  (',', 'NN'),
#  ('[', 'NN'),
#  ('27', 'NN'),
#  (']', 'NN'),
#  ('the', 'NN'),
#  ('son', 'NN'),
#  ('of', 'NN'),
#  ('Maye', 'NN'),
#  ('Musk', 'NN'),
#  ('(', 'NN'),
#  ('née', 'NN'),
#  ('Haldeman', 'NN'),
#  (')', 'NN'),
#  (',', 'NN'),
#  ('a', 'NN'),
#  ('model', 'NN'),
#  ('and', 'NN'),
#  ('dietician', 'NN'),
#  ('from', 'NN'),
#  ('Regina', 'NN'),
#  (',', 'NN'),
#  ('Saskatchewan', 'NN'),
#  (',', 'NN'),
#  ('Canada', 'NN'),
#  (';', 'NN'),
#  ('[', 'NN'),
#  ('28', 'NN'),
#  (']', 'NN'),
#  ('and', 'NN'),
#  ('Errol', 'NN'),
#  ('Musk', 'NN'),
#  (',', 'NN'),
#  ('a', 'NN'),
#  ('South', 'NN'),
#  ('African', 'NN'),
#  ('electromechanical', 'NN'),
#  ('engineer', 'NN'),
#  (',', 'NN'),
#  ('pilot', 'NN'),
#  ('and', 'NN'),
#  ('sailor', 'NN'),
#  ('.', 'NN'),
#  ('He', 'NN'),
#  ('has', 'NN'),
#  ('a', 'NN'),
#  ('younger', 'NN'),
#  ('brother', 'NN'),
#  (',', 'NN'),
#  ('Kimbal', 'NN'),
#  ('(', 'NN'),
#  ('born', 'NN'),
#  ('1972', 'NN'),
#  (')', 'NN'),
#  (',', 'NN'),
#  ('and', 'NN'),
#  ('a', 'NN'),
#  ('younger', 'NN'),
#  ('sister', 'NN'),
#  (',', 'NN'),
#  ('Tosca', 'NN'),
#  ('(', 'NN'),
#  ('born', 'NN'),
#  ('1974', 'NN'),
#  (')', 'NN'),
#  ('.', 'NN'),
#  ('[', 'NN'),
#  ('28', 'NN'),
#  (']', 'NN'),
#  ('[', 'NN'),
#  ('29', 'NN'),
#  (']', 'NN'),
#  ('[', 'NN'),
#  ('30', 'NN'),
#  (']', 'NN'),
#  ('[', 'NN'),
#  ('31', 'NN'),
#  (']', 'NN'),
#  ('His', 'NN'),
#  ('paternal', 'NN'),
#  ('grandmother', 'NN'),
#  ('was', 'NN'),
#  ('British', 'NN'),
#  (',', 'NN'),
#  ('and', 'NN'),
#  ('he', 'NN'),
#  ('also', 'NN'),
#  ('has', 'NN'),
#  ('Pennsylvania', 'NN'),
#  ('Dutch', 'NN'),
#  ('ancestry', 'NN'),
#  (',', 'NN'),
#  ('[', 'NN'),
#  ('32', 'NN'),
#  (']', 'NN'),
#  ('[', 'NN'),
#  ('33', 'NN'),
#  (']', 'NN'),
#  ('and', 'NN'),
#  ('his', 'NN'),
#  ('maternal', 'NN'),
#  ('grandfather', 'NN'),
#  ('was', 'NN'),
#  ('American', 'NN'),
#  (',', 'NN'),
#  ('from', 'NN'),
#  ('Minnesota', 'NN'),
#  ('.', 'NN'),
#  ('[', 'NN'),
#  ('34', 'NN'),
#  (']', 'NN'),
#  ('After', 'NN'),
#  ('his', 'NN'),
#  ('parents', 'NN'),
#  ('divorced', 'NN'),
#  ('in', 'NN'),
#  ('1980', 'NN'),
#  (',', 'NN'),
#  ('Musk', 'NN'),
#  ('lived', 'NN'),
#  ('mostly', 'NN'),
#  ('with', 'NN'),
#  ('his', 'NN'),
#  ('father', 'NN'),
#  ('in', 'NN'),
#  ('the', 'NN'),
#  ('suburbs', 'NN'),
#  ('of', 'NN'),
#  ('Pretoria', 'NN'),
#  ('.', 'NN'),
#  ('[', 'NN'),
#  ('32', 'NN'),
#  (']', 'NN'),
#  ('.During', 'NN'),
#  ('his', 'NN'),
#  ('childhood', 'NN'),
#  ('he', 'NN'),
#  ('had', 'NN'),
#  ('an', 'NN'),
#  ('interest', 'NN'),
#  ('in', 'NN'),
#  ('reading', 'NN'),
#  ('and', 'NN'),
#  ('often', 'NN'),
#  ('did', 'NN'),
#  ('so', 'NN'),
#  ('for', 'NN'),
#  ('hours', 'NN'),
#  ('at', 'NN'),
#  ('a', 'NN'),
#  ('time', 'NN'),
#  ('.', 'NN'),
#  ('[', 'NN'),
#  ('35', 'NN'),
#  (']', 'NN'),
#  ('.At', 'NN'),
#  ('What', 'NN'),
#  ('age', 'NN'),
#  ('did', 'NN'),
#  ('Musk', 'NN'),
#  ('got', 'NN'),
#  ('interested', 'NN'),
#  ('in', 'NN'),
#  ('computing', 'NN'),
#  ('?', 'NN'),
#  ('At', 'NN'),
#  ('age', 'NN'),
#  ('10', 'NN'),
#  (',', 'NN'),
#  ('he', 'NN'),
#  ('developed', 'NN'),
#  ('an', 'NN'),
#  ('interest', 'NN'),
#  ('in', 'NN'),
#  ('computing', 'NN'),
#  ('with', 'NN'),
#  ('the', 'NN'),
#  ('Commodore', 'NN'),
#  ('VIC-20', 'NN'),
#  ('.', 'NN'),
#  ('[', 'NN'),
#  ('36', 'NN'),
#  (']', 'NN'),
#  ('He', 'NN'),
#  ('taught', 'NN'),
#  ('himself', 'NN'),
#  ('computer', 'NN'),
#  ('programming', 'NN'),
#  ('at', 'NN'),
#  ('the', 'NN'),
#  ('age', 'NN'),
#  ('of', 'NN'),
#  ('12', 'NN'),
#  (',', 'NN'),
#  ('sold', 'NN'),
#  ('the', 'NN'),
#  ('code', 'NN'),
#  ('for', 'NN'),
#  ('a', 'NN'),
#  ('BASIC-based', 'NN'),
#  ('video', 'NN'),
#  ('game', 'NN'),
#  ('he', 'NN'),
#  ('created', 'NN'),
#  ('called', 'NN'),
#  ('Blastar', 'NN'),
#  (',', 'NN'),
#  ('to', 'NN'),
#  ('a', 'NN'),
#  ('magazine', 'NN'),
#  ('called', 'NN'),
#  ('PC', 'NN'),
#  ('and', 'NN'),
#  ('Office', 'NN'),
#  ('Technology', 'NN'),
#  (',', 'NN'),
#  ('for', 'NN'),
#  ('approximately', 'NN'),
#  ('$', 'NN'),
#  ('500', 'NN'),
#  ('.', 'NN'),
#  ('[', 'NN'),
#  ('37', 'NN'),
#  (']', 'NN'),
#  ('[', 'NN'),
#  ('38', 'NN'),
#  (']', 'NN'),
#  ('A', 'NN'),
#  ('web', 'NN'),
#  ('version', 'NN'),
#  ('of', 'NN'),
#  ('the', 'NN'),
#  ('game', 'NN'),
#  ('is', 'NN'),
#  ('available', 'NN'),
#  ('online', 'NN'),
#  ('.', 'NN'),
#  ('[', 'NN'),
#  ('37', 'NN'),
#  (']', 'NN'),
#  ('[', 'NN'),
#  ('39', 'NN'),
#  (']', 'NN'),
#  ('.Musk', 'NN'),
#  ('was', 'NN'),
#  ('severely', 'NN'),
#  ('bullied', 'NN'),
#  ('throughout', 'NN'),
#  ('his', 'NN'),
#  ('childhood', 'NN'),
#  (',', 'NN'),
#  ('and', 'NN'),
#  ('was', 'NN'),
#  ('once', 'NN'),
#  ('hospitalized', 'NN'),
#  ('when', 'NN'),
#  ('a', 'NN'),
#  ('group', 'NN'),
#  ('of', 'NN'),
#  ('boys', 'NN'),
#  ('threw', 'NN'),
#  ('him', 'NN'),
#  ('down', 'NN'),
#  ('a', 'NN'),
#  ('flight', 'NN'),
#  ('of', 'NN'),
#  ('stairs', 'NN'),
#  ('and', 'NN'),
#  ('then', 'NN'),
#  ('beat', 'NN'),
#  ('him', 'NN'),
#  ('until', 'NN'),
#  ('he', 'NN'),
#  ('lost', 'NN'),
#  ('consciousness', 'NN'),
#  ('.', 'NN'),
#  ('[', 'NN'),
#  ('40', 'NN'),
#  (']', 'NN'),
#  ('.Musk', 'NN'),
#  ('was', 'NN'),
#  ('initially', 'NN'),
#  ('educated', 'NN'),
#  ('at', 'NN'),
#  ('private', 'NN'),
#  ('schools', 'NN'),
#  (',', 'NN'),
#  ('attending', 'NN'),
#  ('the', 'NN'),
#  ('English-speaking', 'NN'),
#  ('Waterkloof', 'NN'),
#  ('House', 'NN'),
#  ('Preparatory', 'NN'),
#  ('School.Mr', 'NN'),
#  ('.', 'NN'),
#  ('Singh', 'NN'),
#  ('helped', 'NN'),
#  ('Musk', 'NN'),
#  ('during', 'NN'),
#  ('his', 'NN'),
#  ('initial', 'NN'),
#  ('days', 'NN'),
#  ('when', 'NN'),
#  ('he', 'NN'),
#  ('was', 'NN'),
#  ('severely', 'NN'),
#  ('bullied', 'NN'),
#  ('during', 'NN'),
#  ('his', 'NN'),
#  ('childhood.Musk', 'NN'),
#  ('later', 'NN'),
#  ('graduated', 'NN'),
#  ('from', 'NN'),
#  ('Pretoria', 'NN'),
#  ('Boys', 'NN'),
#  ('High', 'NN'),
#  ('School', 'NN'),
#  ('and', 'NN'),
#  ('moved', 'NN'),
#  ('to', 'NN'),
#  ('Canada', 'NN'),
#  ('in', 'NN'),
#  ('June', 'NN'),
#  ('1989', 'NN'),
#  (',', 'NN'),
#  ('just', 'NN'),
#  ('before', 'NN'),
#  ('his', 'NN'),
#  ('18th', 'NN'),
#  ('birthday', 'NN'),
#  (',', 'NN'),
#  ('[', 'NN'),
#  ('41', 'NN'),
#  (']', 'NN'),
#  ('after', 'NN'),
#  ('obtaining', 'NN'),
#  ('Canadian', 'NN'),
#  ('citizenship', 'NN'),
#  ('through', 'NN'),
#  ('his', 'NN'),
#  ('Canadian-born', 'NN'),
#  ('mother', 'NN'),
#  ('.', 'NN'),
#  ('[', 'NN'),
#  ('42', 'NN'),
#  (']', 'NN'),
#  ('[', 'NN'),
#  ('43', 'NN'),
#  (']', 'NN'),
#  ('Although', 'NN'),
#  ('at', 'NN'),
#  ('the', 'NN'),
#  ('time', 'NN'),
#  ('Musk', 'NN'),
#  ('had', 'NN'),
#  ('to', 'NN'),
#  ('register', 'NN'),
#  ('to', 'NN'),
#  ('become', 'NN'),
#  ('a', 'NN'),
#  ('Canadian', 'NN'),
#  ('citizen', 'NN'),
#  (',', 'NN'),
#  ('Bill', 'NN'),
#  ('C-37', 'NN'),
#  (',', 'NN'),
#  ('which', 'NN'),
#  ('came', 'NN'),
#  ('into', 'NN'),
#  ('law', 'NN'),
#  ('in', 'NN'),
#  ('April', 'NN'),
#  ('of', 'NN'),
#  ('2009', 'NN'),
#  (',', 'NN'),
#  ('effectively', 'NN'),
#  ('made', 'NN'),
#  ('his', 'NN'),
#  ('Canadian', 'NN'),
#  ('citizenship', 'NN'),
#  ('retroactive', 'NN'),
#  ('to', 'NN'),
#  ('his', 'NN'),
#  ('birth', 'NN'),
#  ('since', 'NN'),
#  ('he', 'NN'),
#  ('was', 'NN'),
#  ('born', 'NN'),
#  ('in', 'NN'),
#  ('the', 'NN'),
#  ('first', 'NN'),
#  ('generation', 'NN'),
#  ('abroad', 'NN'),
#  ('to', 'NN'),
#  ('a', 'NN'),
#  ('Canadian-born', 'NN'),
#  ('mother', 'NN'),
#  ('.', 'NN'),
#  ('Therefore', 'NN'),
#  (',', 'NN'),
#  ('with', 'NN'),
#  ('the', 'NN'),
#  ('law', 'NN'),
#  ('change', 'NN'),
#  (',', 'NN'),
#  ('he', 'NN'),
#  ('is', 'NN'),
#  ('considered', 'NN'),
#  ('to', 'NN'),
#  ('have', 'NN'),
#  ('always', 'NN'),
#  ('been', 'NN'),
#  ('a', 'NN'),
#  ('Canadian', 'NN'),
#  ('citizen', 'NN'),
#  ('by', 'NN'),
#  ('birth', 'NN'),
#  ('.', 'NN')]

# %% [markdown]
# # part2

# %%
for i in passage1:
    if ((i[len(i)-1]=='s') and (i[len(i)-2]=="'")):
        print(i +' - Possesion Noun (NN$)')
    if i[len(i)-1]=='g' and i[len(i)-2]=="n":
        print(i +'- Gerund (VBG)')
    if i[len(i)-1]=='d' and i[len(i)-2]=="e":
        print(i +'-Simple Past (VBD)')
    if i[len(i)-1]=='d' and i[len(i)-2]=="l":
        print(i +'-Modal (MD)')
    if i[len(i)-1]=='s' and i[len(i)-2]=="e":
        print(i +'-Third Singular Present (VBZ)')
    if i.isdigit():
        print(i +'-Numbers (CD)')
    if i[len(i)-1]=='s':
        print(i +'-Plural Nouns (NNS))')
# Out:
# was-Plural Nouns (NNS))
# 28-Numbers (CD)
# 1971-Numbers (CD)
# Gauteng- Gerund (VBG)
# 27-Numbers (CD)
# 28-Numbers (CD)
# has-Plural Nouns (NNS))
# 1972-Numbers (CD)
# 1974-Numbers (CD)
# 28-Numbers (CD)
# 29-Numbers (CD)
# 30-Numbers (CD)
# 31-Numbers (CD)
# His-Plural Nouns (NNS))
# was-Plural Nouns (NNS))
# has-Plural Nouns (NNS))
# 32-Numbers (CD)
# 33-Numbers (CD)
# his-Plural Nouns (NNS))
# was-Plural Nouns (NNS))
# 34-Numbers (CD)
# his-Plural Nouns (NNS))
# parents-Plural Nouns (NNS))
# divorced-Simple Past (VBD)
# 1980-Numbers (CD)
# lived-Simple Past (VBD)
# his-Plural Nouns (NNS))
# suburbs-Plural Nouns (NNS))
# 32-Numbers (CD)
# .During- Gerund (VBG)
# his-Plural Nouns (NNS))
# reading- Gerund (VBG)
# hours-Plural Nouns (NNS))
# 35-Numbers (CD)
# interested-Simple Past (VBD)
# computing- Gerund (VBG)
# 10-Numbers (CD)
# developed-Simple Past (VBD)
# computing- Gerund (VBG)
# 36-Numbers (CD)
# programming- Gerund (VBG)
# 12-Numbers (CD)
# sold-Modal (MD)
# BASIC-based-Simple Past (VBD)
# created-Simple Past (VBD)
# called-Simple Past (VBD)
# called-Simple Past (VBD)
# 500-Numbers (CD)
# 37-Numbers (CD)
# 38-Numbers (CD)
# is-Plural Nouns (NNS))
# 37-Numbers (CD)
# 39-Numbers (CD)
# was-Plural Nouns (NNS))
# bullied-Simple Past (VBD)
# his-Plural Nouns (NNS))
# was-Plural Nouns (NNS))
# hospitalized-Simple Past (VBD)
# boys-Plural Nouns (NNS))
# stairs-Plural Nouns (NNS))
# consciousness-Plural Nouns (NNS))
# 40-Numbers (CD)
# was-Plural Nouns (NNS))
# educated-Simple Past (VBD)
# schools-Plural Nouns (NNS))
# attending- Gerund (VBG)
# English-speaking- Gerund (VBG)
# helped-Simple Past (VBD)
# during- Gerund (VBG)
# his-Plural Nouns (NNS))
# days-Plural Nouns (NNS))
# was-Plural Nouns (NNS))
# bullied-Simple Past (VBD)
# during- Gerund (VBG)
# his-Plural Nouns (NNS))
# graduated-Simple Past (VBD)
# Boys-Plural Nouns (NNS))
# moved-Simple Past (VBD)
# 1989-Numbers (CD)
# his-Plural Nouns (NNS))
# 41-Numbers (CD)
# obtaining- Gerund (VBG)
# his-Plural Nouns (NNS))
# 42-Numbers (CD)
# 43-Numbers (CD)
# 2009-Numbers (CD)
# his-Plural Nouns (NNS))
# his-Plural Nouns (NNS))
# was-Plural Nouns (NNS))
# is-Plural Nouns (NNS))
# considered-Simple Past (VBD)
# always-Plural Nouns (NNS))
